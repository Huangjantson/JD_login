# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt 
import datetime
from sklearn.metrics import fbeta_score,roc_auc_score
#from mochi import f_beta_01
import re

# %%
from scipy.stats import boxcox
from sklearn.preprocessing import normalize

# %%
from mochi import check_nan_inf

# %%
class Config:
    pass
config = pd.read_pickle('config.pkl')
data_path = config.data_path
feature_path = config.feature_path

# %%
normalized_path = '../../kaggleData/JD_logging/normalized/'

# %%
features =   (config.feature_dict['trade_detail_feature']+
              config.feature_dict['recent_login_detail']+
              config.feature_dict['trade_and_recent_login_comparing']+
              config.feature_dict['login_trade_hist_stats']+
              config.feature_dict['llc_user_habbit']+
              config.feature_dict['hcc_user_habbit']+
              config.feature_dict['hcc_properties']+
              config.feature_dict['hcc_target_encoding']+
              config.feature_dict['login_detail_new_features']+
              config.feature_dict['hcc_trade_properties']+
              config.feature_dict['hcc_mult_target_encoding']+
              config.feature_dict['hcc_user_trade_habbit']
             )
feature_sequence_list = []
for feature in features:
    feature_sequence_list.append(pd.read_pickle(feature_path+feature+'.pkl').reshape(-1,1))
    
trade_tt_mat = np.hstack(feature_sequence_list)
#trade_tt_mat[trade_tt_mat==-10]=np.nan

validation_tuple_list = config.single_module_validation_indice_set
train_labels = pd.read_pickle(data_path+'trade_train_label.pkl')

# %% [markdown]
# ### generating the feature set

# %%
#checking the filled nan by -10, computing the emptyness
trade_df = pd.DataFrame(trade_tt_mat,columns = features)
trade_df[trade_df ==-10] = np.nan
train_trade = trade_df.iloc[config.train_2_6_index]

# %%
#print(dir(config))
print('Currently has feature-sets')
print(config.feature_dict.keys())
# Out:
# Currently has feature-sets
# dict_keys(['trade_and_recent_login_comparing', 'recent_login_detail', 'trade_detail_feature', 'login_trade_hist_stats', 'llc_user_habbit', 'hcc_user_habbit', 'hcc_properties', 'hcc_target_encoding', 'login_detail_new_features', 'hcc_mult_target_encoding', 'hcc_user_trade_habbit', 'hcc_trade_properties'])

# %%
processed_features = []
#processed_feature_names = []

# %% [markdown]
# ### Check data type for features

# %%
types = trade_df['device_comparing_login_1'].apply(lambda x : type(x)).unique()

# %%
type_list = []
type_set =set([])
for feature in features:
    unique_list = list(trade_df[feature].apply(lambda x : type(x)).unique())
    type_list.append((feature,unique_list))
    type_set.update(unique_list)

# %% [markdown]
# ### dealing with boolean features

# %%
#boolean features
boolean_features = []
for feature,unique_types in type_list:
    if bool in unique_types:
        boolean_features.append((feature,unique_types))
boolean_features
# Out:
# [('is_scan_login_0', [float, bool]),
#  ('is_scan_login_1', [float, bool]),
#  ('is_scan_login_2', [float, bool]),
#  ('has_trade_login_0', [float, bool]),
#  ('has_trade_login_1', [float, bool]),
#  ('has_trade_login_2', [float, bool]),
#  ('device_comparing_login_1', [bool]),
#  ('device_comparing_login_2', [bool]),
#  ('ip_comparing_login_1', [bool]),
#  ('ip_comparing_login_2', [bool]),
#  ('city_comparing_login_1', [bool]),
#  ('city_comparing_login_2', [bool]),
#  ('log_from_comparing_login_1', [bool]),
#  ('log_from_comparing_login_2', [bool]),
#  ('result_comparing_login_1', [bool]),
#  ('result_comparing_login_2', [bool]),
#  ('type_comparing_login_1', [bool]),
#  ('type_comparing_login_2', [bool]),
#  ('multiple_fails_1', [bool]),
#  ('multiple_fails_15', [bool]),
#  ('multiple_fails_3', [bool]),
#  ('multiple_fails_30', [bool]),
#  ('multiple_fails_360', [bool]),
#  ('multiple_fails_7', [bool])]

# %%
#filling the -10 to be false
feature_with_nan = [x[0] for x in boolean_features if float in x[1]]

# %%
for feature in feature_with_nan:
    trade_df[feature]= trade_df[feature].fillna(False)

# %%
processed_features.extend(x[0] for x in boolean_features)

# %% [markdown]
# ### dealing with other types, check numerical or categorical first

# %%
#check numerical or categorical by getting the unique value size
other_features = [x[0] for x in type_list if bool not in x[1]]

# %%
other_features_unique_size = [(x,trade_df[x].unique().shape[0]) for x in other_features]
other_features_unique_size = sorted(other_features_unique_size,key = lambda x:x[1],)

# %%
other_features_unique_size
# Out:
# [('type_login_0', 4),
#  ('type_login_1', 4),
#  ('type_login_2', 4),
#  ('recent_login_number', 4),
#  ('weekday_cycle', 6),
#  ('fail_-1_rate_30', 6),
#  ('weekday', 7),
#  ('weekday_cycle_login_0', 7),
#  ('weekday_cycle_login_1', 7),
#  ('weekday_cycle_login_2', 7),
#  ('fail_-1_count_30', 7),
#  ('result_login_0', 8),
#  ('result_login_1', 8),
#  ('weekday_login_0', 8),
#  ('weekday_login_1', 8),
#  ('weekday_login_2', 8),
#  ('fail_-1_count_360', 9),
#  ('log_from_login_0', 10),
#  ('log_from_login_2', 10),
#  ('result_login_2', 10),
#  ('log_from_login_1', 11),
#  ('login_fail_times_1', 11),
#  ('fail_-1_rate_360', 12),
#  ('login_fail_times_3', 14),
#  ('login_fail_times_7', 17),
#  ('fail_-2_rate_30', 17),
#  ('city_freq_rank_7', 18),
#  ('login_fail_times_15', 19),
#  ('city_freq_rank_30_t_t', 20),
#  ('fail_-2_count_30', 21),
#  ('login_fail_times_30', 22),
#  ('city_freq_rank_30', 22),
#  ('city_used_count_7', 22),
#  ('hour', 24),
#  ('hour_cycle', 24),
#  ('city_used_count_30_t_t', 24),
#  ('hour_login_0', 25),
#  ('hour_login_1', 25),
#  ('hour_login_2', 25),
#  ('hour_cycle_login_0', 25),
#  ('hour_cycle_login_1', 25),
#  ('hour_cycle_login_2', 25),
#  ('ip_diff_id_counts_7', 26),
#  ('city_freq_rank_360_t_t', 27),
#  ('city_used_count_30', 28),
#  ('fail_-2_count_360', 29),
#  ('day_cycle', 30),
#  ('login_fail_times_360', 30),
#  ('city_freq_rank_360', 30),
#  ('day', 31),
#  ('day_cycle_login_0', 31),
#  ('day_cycle_login_1', 31),
#  ('day_cycle_login_2', 31),
#  ('ip_diff_id_counts_30_t', 31),
#  ('day_login_0', 32),
#  ('day_login_1', 32),
#  ('day_login_2', 32),
#  ('city_used_count_360_t_t', 32),
#  ('fail_-2_rate_360', 33),
#  ('ip_diff_id_counts_30', 34),
#  ('city_used_count_360', 35),
#  ('device_freq_rank_7', 37),
#  ('device_used_count_7', 41),
#  ('trade_login_fail_rate_1', 47),
#  ('login_success_rate_1', 48),
#  ('login_success_times_1', 50),
#  ('login_times_1', 50),
#  ('is_scan_count_30', 52),
#  ('log_from_10_count_30', 52),
#  ('ip_diff_id_counts_360_t', 54),
#  ('log_from_11_count_30', 57),
#  ('ip_repeat_count_7', 57),
#  ('ip_same_id_login_count_7', 57),
#  ('ip_most_used_id_counts_7', 58),
#  ('ip_diff_id_counts_360', 61),
#  ('after_fail_std_1', 62),
#  ('ip_login_count_7', 65),
#  ('device_freq_rank_30_t_t', 66),
#  ('ip_most_freq_count_7', 68),
#  ('trade_login_fail_rate_3', 69),
#  ('device_repeat_count_7', 69),
#  ('device_same_id_login_count_7', 69),
#  ('login_success_rate_3', 70),
#  ('success_31_count_30', 70),
#  ('log_from_11_count_360', 71),
#  ('period_4_login_times_30', 74),
#  ('device_used_count_30_t_t', 75),
#  ('ip_freq_rank_7', 77),
#  ('device_most_freq_count_7', 82),
#  ('device_freq_rank_30', 84),
#  ('period_4_trade_times_30', 90),
#  ('device_used_count_30', 91),
#  ('ip_used_count_7', 91),
#  ('ip_repeat_count_30_t_t', 96),
#  ('ip_same_id_login_count_30_t', 97),
#  ('ip_most_used_id_counts_30_t', 99),
#  ('ip_most_freq_count_30_t_t', 103),
#  ('login_success_times_3', 104),
#  ('login_times_3', 104),
#  ('ip_repeat_count_30', 109),
#  ('ip_same_id_login_count_30', 109),
#  ('ip_most_used_id_counts_30', 110),
#  ('is_scan_count_360', 115),
#  ('log_from_10_count_360', 115),
#  ('log_from_21_count_30', 115),
#  ('ip_most_freq_count_30', 115),
#  ('period_4_trade_times_360', 116),
#  ('period_2_login_times_30', 117),
#  ('ip_login_count_30_t', 117),
#  ('login_success_rate_7', 118),
#  ('city_repeat_count_7', 118),
#  ('period_1_login_times_30', 125),
#  ('device_same_id_login_count_30_t', 130),
#  ('after_fail_std_3', 132),
#  ('device_repeat_count_30_t_t', 132),
#  ('city_most_freq_count_7', 133),
#  ('ip_login_count_30', 139),
#  ('period_2_trade_times_30', 141),
#  ('log_from_11_rate_30', 142),
#  ('period_0_login_times_30', 146),
#  ('period_2_trade_times_360', 150),
#  ('device_most_freq_count_30_t_t', 151),
#  ('device_repeat_count_30', 153),
#  ('device_same_id_login_count_30', 153),
#  ('ip_freq_rank_30_t_t', 154),
#  ('trade_times_1', 157),
#  ('ip_max_min_dist_7', 158),
#  ('ip_freq_rank_30', 160),
#  ('ip_used_count_30_t_t', 170),
#  ('ip_same_id_login_rate_7', 171),
#  ('device_freq_rank_360_t_t', 173),
#  ('success_31_count_360', 174),
#  ('device_most_freq_count_30', 175),
#  ('ip_used_count_30', 177),
#  ('ip_most_used_id_rate_7', 177),
#  ('device_max_min_dist_7', 182),
#  ('login_success_times_7', 186),
#  ('login_times_7', 186),
#  ('log_from_21_count_360', 188),
#  ('period_1_trade_times_30', 189),
#  ('device_used_count_360_t_t', 192),
#  ('log_from_2_count_30', 194),
#  ('trade_login_fail_rate_7', 195),
#  ('ip_repeat_count_360_t_t', 198),
#  ('period_3_login_times_30', 199),
#  ('type_3_count_30', 201),
#  ('device_freq_rank_360', 201),
#  ('ip_most_used_id_counts_360_t', 201),
#  ('ip_same_id_login_count_360_t', 201),
#  ('ip_max_min_dist_30_t_t', 201),
#  ('type_1_count_30', 212),
#  ('period_4_login_times_360', 213),
#  ('device_used_count_360', 213),
#  ('login_success_rate_15', 215),
#  ('ip_most_freq_count_360_t_t', 219),
#  ('ip_repeat_count_360', 227),
#  ('ip_most_used_id_counts_360', 227),
#  ('ip_same_id_login_count_360', 227),
#  ('period_1_trade_times_360', 233),
#  ('ip_login_count_360_t', 234),
#  ('city_repeat_count_30_t_t', 239),
#  ('after_fail_std_7', 241),
#  ('period_2_login_times_360', 242),
#  ('ip_max_min_dist_30', 245),
#  ('ip_most_freq_count_360', 250),
#  ('trade_times_3', 262),
#  ('period_3_trade_times_30', 262),
#  ('city_most_freq_count_30_t_t', 265),
#  ('ip_login_count_360', 266),
#  ('period_1_login_times_360', 269),
#  ('city_repeat_count_30', 275),
#  ('type_2_count_30', 276),
#  ('ip_freq_rank_360_t_t', 281),
#  ('after_fail_min_1', 284),
#  ('login_success_times_15', 285),
#  ('login_times_15', 286),
#  ('ip_same_id_login_rate_30_t', 287),
#  ('device_same_id_login_count_360_t', 288),
#  ('device_repeat_count_360_t_t', 292),
#  ('log_from_21_rate_30', 296),
#  ('after_fail_max_1', 301),
#  ('after_fail_med_1', 303),
#  ('period_3_trade_times_360', 303),
#  ('log_from_11_rate_360', 304),
#  ('city_most_freq_count_30', 307),
#  ('after_fail_mean_1', 310),
#  ('log_from_1_count_30', 310),
#  ('ip_freq_rank_360', 310),
#  ('ip_most_used_id_rate_30_t', 327),
#  ('device_repeat_count_360', 331),
#  ('device_same_id_login_count_360', 331),
#  ('ip_same_id_login_rate_30', 344),
#  ('ip_max_min_dist_360_t_t', 345),
#  ('device_max_min_dist_30_t_t', 350),
#  ('city_max_min_dist_7', 351),
#  ('login_success_rate_30', 360),
#  ('ip_used_count_360_t_t', 362),
#  ('period_0_login_times_360', 369),
#  ('device_most_freq_count_360_t_t', 372),
#  ('ip_most_used_id_rate_30', 376),
#  ('ip_used_count_360', 385),
#  ('login_success_times_30', 401),
#  ('trade_times_7', 401),
#  ('period_3_login_times_360', 403),
#  ('period_0_trade_times_30', 404),
#  ('success_1_count_30', 404),
#  ('login_times_30', 409),
#  ('ip_max_min_dist_360', 414),
#  ('period_0_trade_times_360', 416),
#  ('device_most_freq_count_360', 435),
#  ('device_max_min_dist_30', 442),
#  ('trade_login_fail_rate_15', 455),
#  ('after_fail_std_15', 466),
#  ('log_from_21_rate_360', 466),
#  ('type_3_count_360', 471),
#  ('type_2_count_360', 476),
#  ('log_from_2_count_360', 482),
#  ('is_scan_rate_30', 484),
#  ('log_from_10_rate_30', 484),
#  ('timelong_login_0_mod_1000', 502),
#  ('timelong_login_1_mod_1000', 502),
#  ('timelong_login_2_mod_1000', 502),
#  ('type_1_count_360', 503),
#  ('city_repeat_count_360_t_t', 510),
#  ('type_2_rate_30', 531),
#  ('after_fail_min_3', 532),
#  ('ip_same_id_login_rate_360_t', 534),
#  ('city_most_freq_count_360_t_t', 535),
#  ('after_fail_max_3', 566),
#  ('city_repeat_count_360', 583),
#  ('after_fail_med_3', 585),
#  ('ip_most_used_id_rate_360_t', 592),
#  ('after_fail_mean_3', 593),
#  ('city_most_freq_rate_7', 601),
#  ('city_most_freq_count_360', 621),
#  ('log_from_1_count_360', 653),
#  ('ip_same_id_login_rate_360', 654),
#  ('trade_login_success_rate_1', 655),
#  ('trade_login_rate_1', 661),
#  ('trade_login_fail_rate_30', 667),
#  ('device_max_min_dist_360_t_t', 679),
#  ('ip_repeat_rate_7', 682),
#  ('trade_times_15', 690),
#  ('city_repeat_rate_7', 690),
#  ('ip_most_freq_rate_7', 693),
#  ('device_most_freq_rate_7', 715),
#  ('city_max_min_dist_30_t_t', 715),
#  ('ip_most_used_id_rate_360', 720),
#  ('device_repeat_rate_7', 736),
#  ('success_1_count_360', 782),
#  ('after_fail_std_30', 788),
#  ('login_success_times_360', 797),
#  ('login_times_360', 798),
#  ('device_max_min_dist_360', 817),
#  ('type_3_rate_30', 864),
#  ('city_max_min_dist_30', 872),
#  ('device_most_used_id_counts_7', 899),
#  ('after_fail_min_7', 917),
#  ('type_1_rate_30', 964),
#  ('after_fail_max_7', 989),
#  ('trade_times_30', 1013),
#  ('after_fail_med_7', 1025),
#  ('after_fail_mean_7', 1044),
#  ('trade_login_fail_rate_360', 1085),
#  ('trade_times_360', 1095),
#  ('device_most_used_id_counts_360_t', 1183),
#  ('device_diff_id_counts_7', 1194),
#  ('login_success_rate_360', 1250),
#  ('success_31_rate_30', 1268),
#  ('device_most_used_id_counts_360', 1317),
#  ('success_1_rate_30', 1322),
#  ('ip_repeat_rate_30_t_t', 1324),
#  ('period_4_login_rate_30', 1328),
#  ('city_most_freq_rate_30_t_t', 1352),
#  ('device_most_used_id_counts_30_t', 1367),
#  ('after_fail_min_15', 1378),
#  ('period_2_login_rate_30', 1423),
#  ('trade_login_success_rate_3', 1425),
#  ('trade_login_rate_3', 1430),
#  ('period_1_login_rate_30', 1467),
#  ('ip_most_freq_rate_30_t_t', 1481),
#  ('city_max_min_dist_360_t_t', 1494),
#  ('device_most_used_id_counts_30', 1512),
#  ('city_repeat_rate_30_t_t', 1526),
#  ('after_fail_max_15', 1551),
#  ('is_scan_rate_360', 1564),
#  ('log_from_10_rate_360', 1564),
#  ('after_fail_med_15', 1599),
#  ('type_2_rate_360', 1640),
#  ('after_fail_mean_15', 1644),
#  ('ip_repeat_rate_30', 1651),
#  ('device_most_freq_rate_30_t_t', 1661),
#  ('device_repeat_rate_30_t_t', 1666),
#  ('city_most_freq_rate_30', 1702),
#  ('city_max_min_dist_360', 1771),
#  ('period_0_login_rate_30', 1802),
#  ('period_3_login_rate_30', 1807),
#  ('ip_most_freq_rate_30', 1841),
#  ('after_fail_std_360', 1894),
#  ('city_repeat_rate_30', 1932),
#  ('log_from_2_rate_30', 1956),
#  ('log_from_1_rate_30', 1968),
#  ('after_fail_min_30', 1986),
#  ('device_most_freq_rate_30', 2044),
#  ('device_repeat_rate_30', 2065),
#  ('device_diff_id_counts_30_t', 2216),
#  ('after_fail_max_30', 2249),
#  ('period_4_trade_rate_30', 2260),
#  ('trade_login_success_rate_7', 2331),
#  ('device_diff_id_counts_30', 2348),
#  ('after_fail_med_30', 2355),
#  ('trade_login_rate_7', 2371),
#  ('after_fail_mean_30', 2424),
#  ('device_id_city_t_encoding', 2454),
#  ('ip_id_t_encoding', 2469),
#  ('device_id_t_encoding', 2532),
#  ('device_login_count_7', 2548),
#  ('type_3_rate_360', 2655),
#  ('type_1_rate_360', 2925),
#  ('period_2_trade_rate_30', 2933),
#  ('after_fail_min_360', 2959),
#  ('city_id_t_encoding', 3052),
#  ('ip_repeat_rate_360_t_t', 3151),
#  ('period_1_trade_rate_30', 3222),
#  ('period_4_login_rate_360', 3233),
#  ('device_same_id_login_rate_7', 3280),
#  ('period_3_trade_rate_30', 3349),
#  ('ip_t_encoding', 3437),
#  ('trade_login_success_rate_15', 3456),
#  ('trade_login_rate_15', 3536),
#  ('after_fail_max_360', 3565),
#  ('period_4_trade_rate_360', 3658),
#  ('id_t_encoding', 3672),
#  ('period_0_trade_rate_30', 3689),
#  ('period_1_login_rate_360', 3746),
#  ('success_31_rate_360', 3781),
#  ('city_most_freq_rate_360_t_t', 3786),
#  ('period_2_login_rate_360', 3811),
#  ('device_diff_id_counts_360_t', 3828),
#  ('after_fail_med_360', 3832),
#  ('ip_repeat_rate_360', 3835),
#  ('device_diff_id_counts_360', 3943),
#  ('success_1_rate_360', 3977),
#  ('after_fail_mean_360', 4005),
#  ('ip_most_freq_rate_360_t_t', 4099),
#  ('city_repeat_rate_360_t_t', 4200),
#  ('period_2_trade_rate_360', 4226),
#  ('device_repeat_rate_360_t_t', 4282),
#  ('device_login_count_30_t', 4320),
#  ('device_most_freq_rate_360_t_t', 4511),
#  ('period_1_trade_rate_360', 4540),
#  ('city_most_freq_rate_360', 4576),
#  ('device_login_count_30', 4744),
#  ('log_from_2_rate_360', 4849),
#  ('period_3_login_rate_360', 4905),
#  ('period_0_login_rate_360', 4910),
#  ('period_3_trade_rate_360', 4925),
#  ('ip_most_freq_rate_360', 4973),
#  ('log_from_1_rate_360', 4979),
#  ('device_same_id_login_rate_30_t', 5076),
#  ('city_repeat_rate_360', 5081),
#  ('device_repeat_rate_360', 5181),
#  ('trade_login_success_rate_30', 5265),
#  ('trade_login_rate_30', 5332),
#  ('period_0_trade_rate_360', 5390),
#  ('device_most_freq_rate_360', 5398),
#  ('device_same_id_login_rate_30', 5769),
#  ('device_most_used_id_rate_7', 6086),
#  ('device_most_used_id_rate_30_t', 6180),
#  ('device_most_used_id_rate_360_t', 6371),
#  ('device_login_count_360_t', 6442),
#  ('device_most_used_id_rate_30', 6480),
#  ('device_most_used_id_rate_360', 6617),
#  ('device_login_count_360', 6710),
#  ('device_same_id_login_rate_360_t', 6835),
#  ('device_same_id_login_rate_360', 7442),
#  ('timelong_min_360', 10459),
#  ('trade_login_rate_360', 10712),
#  ('device_t_encoding', 10796),
#  ('trade_login_success_rate_360', 10820),
#  ('ip_device_t_encoding', 11425),
#  ('timelong_min_30', 14941),
#  ('timelong_min_15', 16648),
#  ('timelong_min_7', 18178),
#  ('timelong_min_3', 19290),
#  ('timelong_min_1', 19919),
#  ('timelong_std_1', 21256),
#  ('timelong_max_360', 21823),
#  ('timelong_login_2', 22583),
#  ('timelong_login_1', 23723),
#  ('timelong_max_1', 24599),
#  ('timelong_login_0', 25203),
#  ('timelong_max_3', 26160),
#  ('timelong_max_30', 26524),
#  ('timelong_max_15', 27218),
#  ('timelong_max_7', 27250),
#  ('mean_login_distance', 27561),
#  ('timelong_med_1', 30230),
#  ('timelong_std_3', 32151),
#  ('timelong_med_3', 33705),
#  ('timelong_med_360', 33939),
#  ('timelong_med_7', 36000),
#  ('timelong_mean_1', 36510),
#  ('timelong_med_15', 36970),
#  ('timelong_med_30', 37237),
#  ('timelong_std_7', 41664),
#  ('timelong_mean_3', 44462),
#  ('timelong_std_15', 49769),
#  ('timelong_mean_7', 51235),
#  ('timelong_std_30', 56732),
#  ('timelong_mean_15', 56758),
#  ('login_distance_diff', 57611),
#  ('timelong_mean_30', 61739),
#  ('timelong_std_360', 63795),
#  ('timelong_mean_360', 66501),
#  ('login_distance_0', 84438),
#  ('login_distance_0_al', 93372),
#  ('login_distance_2', 104154),
#  ('login_distance_1', 107397),
#  ('city_t_encoding', 108429),
#  ('login_distance_1_al', 131707),
#  ('login_distance_2_al', 141774)]

# %% [markdown]
# - categorical features including :
# - type_login_
# - log_from_login
# - result_login_

# %%
categorical_features = []
numerical_features = [x[0] for x in other_features_unique_size]
to_be_remap = []

for feature,size in other_features_unique_size:
    
    if re.match('^type_login_.*',feature) or re.match('^log_from_login.*',feature) or  re.match('^result_login_.*',feature):
        categorical_features.append(feature)
        numerical_features.remove(feature)
    if re.match('.*cycle.*',feature):
        numerical_features.remove(feature)
    elif re.match('^hour.*',feature) or re.match('^weekday.*',feature) or re.match('^day.*',feature):
        to_be_remap.append(feature)
        numerical_features.remove(feature)

# %% [markdown]
# ### Apply box_cox on some of the numerical features

# %%
def fill_median_and_apply_boxcox_and_nomalize(feature):
    #deal with nan
    if np.sum(np.isnan(trade_df[feature].astype(float))):
        temp_column = trade_df[feature].fillna(train_trade[feature].dropna().median()).astype(float)
    else:
        temp_column = trade_df[feature].astype(float)
        
    #check the minimun
    if temp_column.min()<=0:
        print('meet value smaller than 0 at %s, minimun is %f' % (feature,temp_column.min()))
        temp_column+= (np.abs(temp_column.min())+1)
       
        
    #apply box_cox for the feature 
    result = normalize(boxcox(temp_column)[0].reshape(-1,1))
    
    return result.reshape(-1,)

# %%
for feature in numerical_features:
    trade_df[feature] = fill_median_and_apply_boxcox_and_nomalize(feature)
processed_features.extend(numerical_features)
# Out:
# meet value smaller than 0 at recent_login_number, minimun is 0.000000
# meet value smaller than 0 at fail_-1_rate_30, minimun is 0.000000
# meet value smaller than 0 at fail_-1_count_30, minimun is 0.000000
# meet value smaller than 0 at fail_-1_count_360, minimun is 0.000000
# meet value smaller than 0 at login_fail_times_1, minimun is 0.000000
# meet value smaller than 0 at fail_-1_rate_360, minimun is 0.000000
# meet value smaller than 0 at login_fail_times_3, minimun is 0.000000
# meet value smaller than 0 at login_fail_times_7, minimun is 0.000000
# meet value smaller than 0 at fail_-2_rate_30, minimun is 0.000000
# meet value smaller than 0 at login_fail_times_15, minimun is 0.000000
# meet value smaller than 0 at fail_-2_count_30, minimun is 0.000000
# meet value smaller than 0 at login_fail_times_30, minimun is 0.000000
# meet value smaller than 0 at ip_diff_id_counts_7, minimun is 0.000000
# meet value smaller than 0 at fail_-2_count_360, minimun is 0.000000
# meet value smaller than 0 at login_fail_times_360, minimun is 0.000000
# meet value smaller than 0 at ip_diff_id_counts_30_t, minimun is 0.000000
# meet value smaller than 0 at fail_-2_rate_360, minimun is 0.000000
# meet value smaller than 0 at ip_diff_id_counts_30, minimun is 0.000000
# meet value smaller than 0 at trade_login_fail_rate_1, minimun is 0.000000
# meet value smaller than 0 at login_success_rate_1, minimun is 0.000000
# meet value smaller than 0 at login_success_times_1, minimun is 0.000000
# meet value smaller than 0 at login_times_1, minimun is 0.000000
# meet value smaller than 0 at is_scan_count_30, minimun is 0.000000
# meet value smaller than 0 at log_from_10_count_30, minimun is 0.000000
# meet value smaller than 0 at ip_diff_id_counts_360_t, minimun is 0.000000
# meet value smaller than 0 at log_from_11_count_30, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_count_7, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_counts_7, minimun is 0.000000
# meet value smaller than 0 at ip_diff_id_counts_360, minimun is 0.000000
# meet value smaller than 0 at ip_login_count_7, minimun is 0.000000
# meet value smaller than 0 at trade_login_fail_rate_3, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_count_7, minimun is 0.000000
# meet value smaller than 0 at login_success_rate_3, minimun is 0.000000
# meet value smaller than 0 at success_31_count_30, minimun is 0.000000
# meet value smaller than 0 at log_from_11_count_360, minimun is 0.000000
# meet value smaller than 0 at period_4_login_times_30, minimun is 0.000000
# meet value smaller than 0 at period_4_trade_times_30, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_count_30_t, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_counts_30_t, minimun is 0.000000
# meet value smaller than 0 at login_success_times_3, minimun is 0.000000
# meet value smaller than 0 at login_times_3, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_count_30, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_counts_30, minimun is 0.000000
# meet value smaller than 0 at is_scan_count_360, minimun is 0.000000
# meet value smaller than 0 at log_from_10_count_360, minimun is 0.000000
# meet value smaller than 0 at log_from_21_count_30, minimun is 0.000000
# meet value smaller than 0 at period_4_trade_times_360, minimun is 0.000000
# meet value smaller than 0 at period_2_login_times_30, minimun is 0.000000
# meet value smaller than 0 at ip_login_count_30_t, minimun is 0.000000
# meet value smaller than 0 at login_success_rate_7, minimun is 0.000000
# meet value smaller than 0 at period_1_login_times_30, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_count_30_t, minimun is 0.000000
# meet value smaller than 0 at ip_login_count_30, minimun is 0.000000
# meet value smaller than 0 at period_2_trade_times_30, minimun is 0.000000
# meet value smaller than 0 at log_from_11_rate_30, minimun is 0.000000
# meet value smaller than 0 at period_0_login_times_30, minimun is 0.000000
# meet value smaller than 0 at period_2_trade_times_360, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_count_30, minimun is 0.000000
# meet value smaller than 0 at trade_times_1, minimun is 0.000000
# meet value smaller than 0 at ip_max_min_dist_7, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_rate_7, minimun is 0.000000
# meet value smaller than 0 at success_31_count_360, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_rate_7, minimun is 0.000000
# meet value smaller than 0 at device_max_min_dist_7, minimun is 0.000000
# meet value smaller than 0 at login_success_times_7, minimun is 0.000000
# meet value smaller than 0 at login_times_7, minimun is 0.000000
# meet value smaller than 0 at log_from_21_count_360, minimun is 0.000000
# meet value smaller than 0 at period_1_trade_times_30, minimun is 0.000000
# meet value smaller than 0 at log_from_2_count_30, minimun is 0.000000
# meet value smaller than 0 at trade_login_fail_rate_7, minimun is 0.000000
# meet value smaller than 0 at period_3_login_times_30, minimun is 0.000000
# meet value smaller than 0 at type_3_count_30, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_counts_360_t, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_count_360_t, minimun is 0.000000
# meet value smaller than 0 at ip_max_min_dist_30_t_t, minimun is 0.000000
# meet value smaller than 0 at type_1_count_30, minimun is 0.000000
# meet value smaller than 0 at period_4_login_times_360, minimun is 0.000000
# meet value smaller than 0 at login_success_rate_15, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_counts_360, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_count_360, minimun is 0.000000
# meet value smaller than 0 at period_1_trade_times_360, minimun is 0.000000
# meet value smaller than 0 at ip_login_count_360_t, minimun is 0.000000
# meet value smaller than 0 at period_2_login_times_360, minimun is 0.000000
# meet value smaller than 0 at ip_max_min_dist_30, minimun is 0.000000
# meet value smaller than 0 at trade_times_3, minimun is 0.000000
# meet value smaller than 0 at period_3_trade_times_30, minimun is 0.000000
# meet value smaller than 0 at ip_login_count_360, minimun is 0.000000
# meet value smaller than 0 at period_1_login_times_360, minimun is 0.000000
# meet value smaller than 0 at type_2_count_30, minimun is 0.000000
# meet value smaller than 0 at after_fail_min_1, minimun is 0.000000
# meet value smaller than 0 at login_success_times_15, minimun is 0.000000
# meet value smaller than 0 at login_times_15, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_rate_30_t, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_count_360_t, minimun is 0.000000
# meet value smaller than 0 at log_from_21_rate_30, minimun is 0.000000
# meet value smaller than 0 at period_3_trade_times_360, minimun is 0.000000
# meet value smaller than 0 at log_from_11_rate_360, minimun is 0.000000
# meet value smaller than 0 at log_from_1_count_30, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_rate_30_t, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_count_360, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_rate_30, minimun is 0.000000
# meet value smaller than 0 at ip_max_min_dist_360_t_t, minimun is 0.000000
# meet value smaller than 0 at device_max_min_dist_30_t_t, minimun is 0.000000
# meet value smaller than 0 at city_max_min_dist_7, minimun is 0.000000
# meet value smaller than 0 at login_success_rate_30, minimun is 0.000000
# meet value smaller than 0 at period_0_login_times_360, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_rate_30, minimun is 0.000000
# meet value smaller than 0 at login_success_times_30, minimun is 0.000000
# meet value smaller than 0 at trade_times_7, minimun is 0.000000
# meet value smaller than 0 at period_3_login_times_360, minimun is 0.000000
# meet value smaller than 0 at period_0_trade_times_30, minimun is 0.000000
# meet value smaller than 0 at success_1_count_30, minimun is 0.000000
# meet value smaller than 0 at login_times_30, minimun is 0.000000
# meet value smaller than 0 at ip_max_min_dist_360, minimun is 0.000000
# meet value smaller than 0 at period_0_trade_times_360, minimun is 0.000000
# meet value smaller than 0 at device_max_min_dist_30, minimun is 0.000000
# meet value smaller than 0 at trade_login_fail_rate_15, minimun is 0.000000
# meet value smaller than 0 at log_from_21_rate_360, minimun is 0.000000
# meet value smaller than 0 at type_3_count_360, minimun is 0.000000
# meet value smaller than 0 at type_2_count_360, minimun is 0.000000
# meet value smaller than 0 at log_from_2_count_360, minimun is 0.000000
# meet value smaller than 0 at is_scan_rate_30, minimun is 0.000000
# meet value smaller than 0 at log_from_10_rate_30, minimun is 0.000000
# meet value smaller than 0 at timelong_login_0_mod_1000, minimun is 0.000000
# meet value smaller than 0 at timelong_login_1_mod_1000, minimun is 0.000000
# meet value smaller than 0 at timelong_login_2_mod_1000, minimun is 0.000000
# meet value smaller than 0 at type_1_count_360, minimun is 0.000000
# meet value smaller than 0 at type_2_rate_30, minimun is 0.000000
# meet value smaller than 0 at after_fail_min_3, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_rate_360_t, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_rate_360_t, minimun is 0.000000
# meet value smaller than 0 at log_from_1_count_360, minimun is 0.000000
# meet value smaller than 0 at ip_same_id_login_rate_360, minimun is 0.000000
# meet value smaller than 0 at trade_login_success_rate_1, minimun is 0.000000
# meet value smaller than 0 at trade_login_rate_1, minimun is 0.000000
# meet value smaller than 0 at trade_login_fail_rate_30, minimun is 0.000000
# meet value smaller than 0 at device_max_min_dist_360_t_t, minimun is 0.000000
# meet value smaller than 0 at trade_times_15, minimun is 0.000000
# meet value smaller than 0 at city_max_min_dist_30_t_t, minimun is 0.000000
# meet value smaller than 0 at ip_most_used_id_rate_360, minimun is 0.000000
# meet value smaller than 0 at success_1_count_360, minimun is 0.000000
# meet value smaller than 0 at login_success_times_360, minimun is 0.000000
# meet value smaller than 0 at login_times_360, minimun is 0.000000
# meet value smaller than 0 at device_max_min_dist_360, minimun is 0.000000
# meet value smaller than 0 at type_3_rate_30, minimun is 0.000000
# meet value smaller than 0 at city_max_min_dist_30, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_counts_7, minimun is 0.000000
# meet value smaller than 0 at after_fail_min_7, minimun is 0.000000
# meet value smaller than 0 at type_1_rate_30, minimun is 0.000000
# meet value smaller than 0 at trade_times_30, minimun is 0.000000
# meet value smaller than 0 at trade_login_fail_rate_360, minimun is 0.000000
# meet value smaller than 0 at trade_times_360, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_counts_360_t, minimun is 0.000000
# meet value smaller than 0 at device_diff_id_counts_7, minimun is 0.000000
# meet value smaller than 0 at login_success_rate_360, minimun is 0.000000
# meet value smaller than 0 at success_31_rate_30, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_counts_360, minimun is 0.000000
# meet value smaller than 0 at success_1_rate_30, minimun is 0.000000
# meet value smaller than 0 at period_4_login_rate_30, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_counts_30_t, minimun is 0.000000
# meet value smaller than 0 at after_fail_min_15, minimun is 0.000000
# meet value smaller than 0 at period_2_login_rate_30, minimun is 0.000000
# meet value smaller than 0 at trade_login_success_rate_3, minimun is 0.000000
# meet value smaller than 0 at trade_login_rate_3, minimun is 0.000000
# meet value smaller than 0 at period_1_login_rate_30, minimun is 0.000000
# meet value smaller than 0 at city_max_min_dist_360_t_t, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_counts_30, minimun is 0.000000
# meet value smaller than 0 at is_scan_rate_360, minimun is 0.000000
# meet value smaller than 0 at log_from_10_rate_360, minimun is 0.000000
# meet value smaller than 0 at type_2_rate_360, minimun is 0.000000
# meet value smaller than 0 at city_max_min_dist_360, minimun is 0.000000
# meet value smaller than 0 at period_0_login_rate_30, minimun is 0.000000
# meet value smaller than 0 at period_3_login_rate_30, minimun is 0.000000
# meet value smaller than 0 at after_fail_std_360, minimun is 0.000000
# meet value smaller than 0 at log_from_2_rate_30, minimun is 0.000000
# meet value smaller than 0 at log_from_1_rate_30, minimun is 0.000000
# meet value smaller than 0 at after_fail_min_30, minimun is 0.000000
# meet value smaller than 0 at device_diff_id_counts_30_t, minimun is 0.000000
# meet value smaller than 0 at period_4_trade_rate_30, minimun is 0.000000
# meet value smaller than 0 at trade_login_success_rate_7, minimun is 0.000000
# meet value smaller than 0 at device_diff_id_counts_30, minimun is 0.000000
# meet value smaller than 0 at trade_login_rate_7, minimun is 0.000000
# meet value smaller than 0 at device_id_city_t_encoding, minimun is 0.000000
# meet value smaller than 0 at ip_id_t_encoding, minimun is 0.000000
# meet value smaller than 0 at device_id_t_encoding, minimun is 0.000000
# meet value smaller than 0 at device_login_count_7, minimun is 0.000000
# meet value smaller than 0 at type_3_rate_360, minimun is 0.000000
# meet value smaller than 0 at type_1_rate_360, minimun is 0.000000
# meet value smaller than 0 at period_2_trade_rate_30, minimun is 0.000000
# meet value smaller than 0 at after_fail_min_360, minimun is 0.000000
# meet value smaller than 0 at city_id_t_encoding, minimun is 0.000000
# meet value smaller than 0 at period_1_trade_rate_30, minimun is 0.000000
# meet value smaller than 0 at period_4_login_rate_360, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_rate_7, minimun is 0.000000
# meet value smaller than 0 at period_3_trade_rate_30, minimun is 0.000000
# meet value smaller than 0 at ip_t_encoding, minimun is 0.000000
# meet value smaller than 0 at trade_login_success_rate_15, minimun is 0.000000
# meet value smaller than 0 at trade_login_rate_15, minimun is 0.000000
# meet value smaller than 0 at after_fail_max_360, minimun is 0.000000
# meet value smaller than 0 at period_4_trade_rate_360, minimun is 0.000000
# meet value smaller than 0 at id_t_encoding, minimun is 0.000000
# meet value smaller than 0 at period_0_trade_rate_30, minimun is 0.000000
# meet value smaller than 0 at period_1_login_rate_360, minimun is 0.000000
# meet value smaller than 0 at success_31_rate_360, minimun is 0.000000
# meet value smaller than 0 at period_2_login_rate_360, minimun is 0.000000
# meet value smaller than 0 at device_diff_id_counts_360_t, minimun is 0.000000
# meet value smaller than 0 at after_fail_med_360, minimun is 0.000000
# meet value smaller than 0 at device_diff_id_counts_360, minimun is 0.000000
# meet value smaller than 0 at success_1_rate_360, minimun is 0.000000
# meet value smaller than 0 at after_fail_mean_360, minimun is 0.000000
# meet value smaller than 0 at period_2_trade_rate_360, minimun is 0.000000
# meet value smaller than 0 at device_login_count_30_t, minimun is 0.000000
# meet value smaller than 0 at period_1_trade_rate_360, minimun is 0.000000
# meet value smaller than 0 at device_login_count_30, minimun is 0.000000
# meet value smaller than 0 at log_from_2_rate_360, minimun is 0.000000
# meet value smaller than 0 at period_3_login_rate_360, minimun is 0.000000
# meet value smaller than 0 at period_0_login_rate_360, minimun is 0.000000
# meet value smaller than 0 at period_3_trade_rate_360, minimun is 0.000000
# meet value smaller than 0 at log_from_1_rate_360, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_rate_30_t, minimun is 0.000000
# meet value smaller than 0 at trade_login_success_rate_30, minimun is 0.000000
# meet value smaller than 0 at trade_login_rate_30, minimun is 0.000000
# meet value smaller than 0 at period_0_trade_rate_360, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_rate_30, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_rate_7, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_rate_30_t, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_rate_360_t, minimun is 0.000000
# meet value smaller than 0 at device_login_count_360_t, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_rate_30, minimun is 0.000000
# meet value smaller than 0 at device_most_used_id_rate_360, minimun is 0.000000
# meet value smaller than 0 at device_login_count_360, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_rate_360_t, minimun is 0.000000
# meet value smaller than 0 at device_same_id_login_rate_360, minimun is 0.000000
# meet value smaller than 0 at timelong_min_360, minimun is 0.000000
# meet value smaller than 0 at trade_login_rate_360, minimun is 0.000000
# meet value smaller than 0 at device_t_encoding, minimun is 0.000000
# meet value smaller than 0 at trade_login_success_rate_360, minimun is 0.000000
# meet value smaller than 0 at ip_device_t_encoding, minimun is 0.000000
# meet value smaller than 0 at timelong_min_30, minimun is 0.000000
# meet value smaller than 0 at timelong_min_15, minimun is 0.000000
# meet value smaller than 0 at timelong_min_7, minimun is 0.000000
# meet value smaller than 0 at timelong_min_3, minimun is 0.000000
# meet value smaller than 0 at timelong_min_1, minimun is 0.000000
# meet value smaller than 0 at timelong_std_1, minimun is 0.000000
# meet value smaller than 0 at timelong_max_360, minimun is 0.000000
# meet value smaller than 0 at timelong_login_2, minimun is -601.000000
# meet value smaller than 0 at timelong_login_1, minimun is -342.000000
# meet value smaller than 0 at timelong_max_1, minimun is 0.000000
# meet value smaller than 0 at timelong_login_0, minimun is -1.000000
# meet value smaller than 0 at timelong_max_3, minimun is 0.000000
# meet value smaller than 0 at timelong_max_30, minimun is 0.000000
# meet value smaller than 0 at timelong_max_15, minimun is 0.000000
# meet value smaller than 0 at timelong_max_7, minimun is 0.000000
# meet value smaller than 0 at mean_login_distance, minimun is 0.000000
# meet value smaller than 0 at timelong_med_1, minimun is 0.000000
# meet value smaller than 0 at timelong_std_3, minimun is 0.000000
# meet value smaller than 0 at timelong_med_3, minimun is 0.000000
# meet value smaller than 0 at timelong_med_360, minimun is 0.000000
# meet value smaller than 0 at timelong_med_7, minimun is 0.000000
# meet value smaller than 0 at timelong_mean_1, minimun is 0.000000
# meet value smaller than 0 at timelong_med_15, minimun is 0.000000
# meet value smaller than 0 at timelong_med_30, minimun is 0.000000
# meet value smaller than 0 at timelong_std_7, minimun is 0.000000
# meet value smaller than 0 at timelong_mean_3, minimun is 0.000000
# meet value smaller than 0 at timelong_std_15, minimun is 0.000000
# meet value smaller than 0 at timelong_mean_7, minimun is 0.000000
# meet value smaller than 0 at timelong_std_30, minimun is 0.000000
# meet value smaller than 0 at timelong_mean_15, minimun is 0.000000
# meet value smaller than 0 at login_distance_diff, minimun is 0.000000
# meet value smaller than 0 at timelong_mean_30, minimun is 0.000000
# meet value smaller than 0 at timelong_std_360, minimun is 0.000000
# meet value smaller than 0 at timelong_mean_360, minimun is 0.000000
# meet value smaller than 0 at login_distance_0, minimun is 0.000000
# meet value smaller than 0 at login_distance_0_al, minimun is 0.000000
# meet value smaller than 0 at city_t_encoding, minimun is 0.000000

# %% [markdown]
# ### remaping some of the features to be new categorical

# %%
def map_hour(hour):
    if hour ==0 or hour>17:
        #18-0
        return 0
    elif hour>14:
        #15-17
        return 1
    elif hour>11:
        #12-15
        return 2
    elif hour>7:
        #8-11
        return 3
    else:
        #1-7
        return 4

def map_weekday(weekday):
    if weekday ==6 or weekday ==7:
        return True
    else:
        return False

def map_day(day):
    if day < 7:
        return 0
    elif day<15:
        return 1
    elif day<22:
        return 2
    else:
        return 3

# %%
for feature in to_be_remap:
    if re.match('^hour.*',feature):
        trade_df[feature] = trade_df[feature].apply(lambda x : map_hour(x))
    elif re.match('^weekday.*',feature):
        trade_df[feature] = trade_df[feature].apply(lambda x : map_weekday(x))
    elif re.match('^day.*',feature):
        trade_df[feature] = trade_df[feature].apply(lambda x : map_day(x))

categorical_features.extend(to_be_remap)

# %% [markdown]
# ### mapping the categorical features

# %%
for feature in categorical_features:
    possible_values = trade_df[feature].unique()
    for value in possible_values:
        trade_df[feature+'_'+str(value)] = (trade_df[feature]==value)
        processed_features.append(feature+'_'+str(value))

# %% [markdown]
# ### Check and generate the result feature set

# %%
trade_tt_mat = trade_df[processed_features]
for feature in [x[0] for x in boolean_features]:
    trade_tt_mat[feature] = trade_tt_mat[feature].apply(lambda x : 1 if x else 0)
check_nan_inf(trade_tt_mat,processed_features)
# Out:
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### generate the normalized features

# %%
for feature in processed_features:
    pd.to_pickle(trade_tt_mat[feature].values,normalized_path+feature+'.pkl')

# %%
config = pd.read_pickle('config.pkl')
config.normalized_path =normalized_path
config.normalized_features = processed_features
config.numerical_features = numerical_features

# %%
pd.to_pickle(config,'config.pkl')
